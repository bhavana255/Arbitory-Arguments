# %%
import matplotlib.pyplot as plt

# %%
y=list(range(20,50,3))
y1=[2,5,1,10,2,7,4,8,3,7]
x=list(range(10))

# %%
len(y1)
# Out:
# 10

# %%
plt.plot(x,y1)
plt.xlabel('x')
plt.ylabel('y label')
# Out:
# Text(0, 0.5, 'y label')

# %%
y=list(range(25,67,30))
y1=[5,8,5,8,9,0,3]
x=list(range(7))

# %%
len(y1)
# Out:
# 7

# %%
plt.plot(x,y1)
plt.xlabel('x')
plt.ylabel('y label')
# Out:
# Text(0, 0.5, 'y label')

# %%
plt.plot(x,y1)

# %%
y=list(range(20,50,3))
y1=[2,5,1,10,2,7,4,8,3,7]
x=list(range(10))

# %%
plt.plot(x,y1)
plt.xlabel('x')
plt.ylabel('y label')
# Out:
# Text(0, 0.5, 'y label')

# %%
plt.scatter(x,y)
